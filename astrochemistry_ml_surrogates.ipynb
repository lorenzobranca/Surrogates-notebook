# %% [markdown]
# # ML Surrogates for Chemical ODEs in Astrochemistry
# Welcome! In this notebook, we simulate a simple astrochemical ODE system and train three different ML models to approximate its behavior:
# - Feedforward Neural Network (FNN)
# - Neural ODE
# - Deep Operator Network (DeepONet)
#
# We'll compare their performance as surrogates for the underlying physical dynamics.
#
# **Author:** Lorenzo Branca
# **Date:** July 2025

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
from diffrax import diffeqsolve, Dopri5, ODETerm, SaveAt
import optax
# %matplotlib inline

# %% [markdown]
# ## Simulating a Toy Chemical Reaction System

# %%
def reaction_system(t, y, args):
    A, B, C = y
    k1, k2 = args
    dA = -k1 * A * B
    dB = -k1 * A * B + k2 * C
    dC = k1 * A * B - k2 * C
    return jnp.array([dA, dB, dC])

y0 = jnp.array([1.0, 1.0, 0.0])
k1, k2 = 0.5, 0.1
t0, t1 = 0.0, 10.0
ts = jnp.linspace(t0, t1, 100)

term = ODETerm(reaction_system)
solver = Dopri5()
saveat = SaveAt(ts=ts)
sol = diffeqsolve(term, solver, t0=t0, t1=t1, dt0=0.1, y0=y0, args=(k1, k2), saveat=saveat)

plt.plot(ts, sol.ys[:, 0], label="A")
plt.plot(ts, sol.ys[:, 1], label="B")
plt.plot(ts, sol.ys[:, 2], label="C")
plt.xlabel("Time")
plt.ylabel("Abundance")
plt.title("Toy Chemical Reaction Dynamics")
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Generate Training Data

# %%
def generate_dataset(n_samples=200):
    ic_list, traj_list = [], []
    for i in range(n_samples):
        B0 = 0.5 + 0.5 * i / n_samples
        y0 = jnp.array([1.0, B0, 0.0])
        sol = diffeqsolve(term, solver, t0=t0, t1=t1, dt0=0.1, y0=y0, args=(k1, k2), saveat=saveat)
        ic_list.append(y0)
        traj_list.append(sol.ys)
    return jnp.stack(ic_list), ts[None, :].repeat(n_samples, axis=0), jnp.stack(traj_list)

ICs, Ts, Ys = generate_dataset(n_samples=200)
print("ICs:", ICs.shape, "Ts:", Ts.shape, "Ys:", Ys.shape)
# Out:
# ICs: (200, 3) Ts: (200, 100) Ys: (200, 100, 3)

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Now that we have generated the data, we will:
#
# 1. Implement and train a **Feedforward Neural Network (FNN)**.
# 2. Implement and train a **Neural ODE** model.
# 3. Implement and train a **DeepONet** model.
# 4. Compare their performance.
#
# ⬇️ Continue by implementing the FNN model below ⬇️

# %% [markdown]
# ## 🔧 Implementing the Feedforward Neural Network (FNN)
# We'll use a simple MLP that takes `[IC, t]` as input and predicts `[A, B, C]`.

# %%
from flax import linen as nn
from dataclasses import field
from typing import List

class FNN(nn.Module):
    hidden_dims: List[int] = field(default_factory=lambda: [128, 128, 128])

    @nn.compact
    def __call__(self, ic, t):
        B, N = t.shape
        x = jnp.concatenate([jnp.repeat(ic[:, None, :], N, axis=1), t[:, :, None]], axis=-1)
        x = x.reshape(-1, x.shape[-1])  # (B*N, features)
        for h in self.hidden_dims:
            x = nn.relu(nn.Dense(h)(x))
        out = nn.Dense(3)(x)
        return out.reshape(B, N, 3)

# %% [markdown]
# ### 🔁 Training loop for FNN

# %%
import optax
from flax.training import train_state

class TrainState(train_state.TrainState):
    pass

def create_train_state(rng, model, lr=1e-3):
    params = model.init(rng, ICs[:1], Ts[:1])['params']
    tx = optax.adam(learning_rate=lr)
    return TrainState.create(apply_fn=model.apply, params=params, tx=tx)

def loss_fn(params, apply_fn, ic, t, y_true):
    y_pred = apply_fn({'params': params}, ic, t)
    return jnp.mean((y_pred - y_true)**2)

@jax.jit
def train_step(state, ic, t, y_true):
    grad_fn = jax.value_and_grad(loss_fn)
    loss, grads = grad_fn(state.params, state.apply_fn, ic, t, y_true)
    return state.apply_gradients(grads=grads), loss

# %% [markdown]
# ### 🚀 Train the model

# %%
rng = jax.random.PRNGKey(0)
model = FNN()
state = create_train_state(rng, model)

n_epochs = 200
batch_size = 32
losses = []

for epoch in range(n_epochs):
    idx = jax.random.permutation(rng, ICs.shape[0])
    ICs_shuffled, Ts_shuffled, Ys_shuffled = ICs[idx], Ts[idx], Ys[idx]

    epoch_loss = 0.0
    for i in range(0, ICs.shape[0], batch_size):
        ic_batch = ICs_shuffled[i:i+batch_size]
        t_batch = Ts_shuffled[i:i+batch_size]
        y_batch = Ys_shuffled[i:i+batch_size]
        state, loss = train_step(state, ic_batch, t_batch, y_batch)
        epoch_loss += loss

    epoch_loss /= (ICs.shape[0] // batch_size)
    losses.append(epoch_loss)
    if epoch % 20 == 0:
        print(f"Epoch {epoch}, Loss = {epoch_loss:.4e}")
# Out:
# Epoch 0, Loss = 4.0518e-01
# Epoch 20, Loss = 2.0062e-03
# Epoch 40, Loss = 8.5064e-05
# Epoch 60, Loss = 4.1702e-05
# Epoch 80, Loss = 2.4241e-05
# Epoch 100, Loss = 1.6514e-05
# Epoch 120, Loss = 1.4826e-05
# Epoch 140, Loss = 1.0274e-05
# Epoch 160, Loss = 1.5468e-05
# Epoch 180, Loss = 2.0312e-05

# %% [markdown]
# ### 📈 Visualize predictions vs. ground truth

# %%
# Pick a test sample
idx = 0
ic_test = ICs[idx:idx+1]
t_test = Ts[idx:idx+1]
y_true = Ys[idx]

y_pred = model.apply({'params': state.params}, ic_test, t_test)[0]

plt.plot(ts, y_true[:, 0], label="A true")
plt.plot(ts, y_true[:, 1], label="B true")
plt.plot(ts, y_true[:, 2], label="C true")
plt.plot(ts, y_pred[:, 0], '--', label="A pred")
plt.plot(ts, y_pred[:, 1], '--', label="B pred")
plt.plot(ts, y_pred[:, 2], '--', label="C pred")
plt.legend()
plt.title("FNN Prediction vs Ground Truth")
plt.xlabel("Time")
plt.ylabel("Abundance")
plt.grid(True)

# %% [markdown]
# ## 🧠 Implementing the Neural ODE Surrogate
# We will define a neural network as the right-hand side of the ODE system and use it inside a `diffrax` solver.

# %%
class NeuralODEFunc(nn.Module):
    hidden_dims: List[int] = field(default_factory=lambda: [64, 64])

    @nn.compact
    def __call__(self, t, y, args=None):
        x = y
        for h in self.hidden_dims:
            x = nn.tanh(nn.Dense(h)(x))
        return nn.Dense(3)(x)

# %%
def solve_neural_ode(rhs_net, params, y0, ts):
    term = ODETerm(lambda t, y, args: rhs_net.apply({'params': params}, t, y))
    solver = Dopri5()
    saveat = SaveAt(ts=ts)
    sol = diffeqsolve(term, solver, t0=ts[0], t1=ts[-1], dt0=0.1, y0=y0, saveat=saveat)
    return sol.ys

# %%
# Initialize
neural_ode_model = NeuralODEFunc()
rng, key = jax.random.split(rng)
neural_ode_params = neural_ode_model.init(key, 0.0, jnp.array([1.0, 1.0, 0.0]))['params']

optimizer = optax.adam(1e-3)
opt_state = optimizer.init(neural_ode_params)

# %%
from functools import partial

@jax.jit
def ode_loss_fn(params, model, y0, ts, y_true):
    pred_y = solve_neural_ode(model, params, y0, ts)
    return jnp.mean((pred_y - y_true) ** 2)

# Define a closure where neural_ode_model is accessible from outer scope
def make_ode_train_step(model):
    @jax.jit
    def ode_train_step(params, opt_state, y0, ts, y_true):
        def loss_fn(params):
            pred_y = solve_neural_ode(model, params, y0, ts)
            return jnp.mean((pred_y - y_true) ** 2)
        loss, grads = jax.value_and_grad(loss_fn)(params)
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)
        return params, opt_state, loss
    return ode_train_step

# %%
# Train Neural ODE
n_epochs = 100
ode_losses = []

for epoch in range(n_epochs):
    epoch_loss = 0.0
    for i in range(0, ICs.shape[0], batch_size):
        ic_batch = ICs[i]
        y_batch = Ys[i]
        ode_train_step = make_ode_train_step(neural_ode_model)
        neural_ode_params, opt_state, loss = ode_train_step(neural_ode_params, opt_state, ic_batch, ts, y_batch)

        epoch_loss += loss
    epoch_loss /= (ICs.shape[0] // batch_size)
    ode_losses.append(epoch_loss)
    if epoch % 20 == 0:
        print(f"[NeuralODE] Epoch {epoch}, Loss = {epoch_loss:.4e}")
# Out:
# [NeuralODE] Epoch 0, Loss = 1.3920e-01
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File /usr/lib/python3.10/runpy.py:196, in _run_module_as_main()
#     195     sys.argv[0] = mod_spec.origin
# --> 196 return _run_code(code, main_globals, None,
#     197                  "__main__", mod_spec)
#
# File /usr/lib/python3.10/runpy.py:86, in _run_code()
#      79 run_globals.update(__name__ = mod_name,
#      80                    __file__ = fname,
#      81                    __cached__ = cached,
#    (...)
#      84                    __package__ = pkg_name,
#      85                    __spec__ = mod_spec)
# ---> 86 exec(code, run_globals)
#      87 return run_globals
#
# File ~/.local/lib/python3.10/site-packages/ipykernel_launcher.py:17
#      15 from ipykernel import kernelapp as app
# ---> 17 app.launch_new_instance()
#
# File ~/.local/lib/python3.10/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File ~/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py:205, in start()
#     204 def start(self) -> None:
# --> 205     self.asyncio_loop.run_forever()
#
# File /usr/lib/python3.10/asyncio/base_events.py:603, in run_forever()
#     602 while True:
# --> 603     self._run_once()
#     604     if self._stopping:
#
# File /usr/lib/python3.10/asyncio/base_events.py:1909, in _run_once()
#    1908     else:
# -> 1909         handle._run()
#    1910 handle = None
#
# File /usr/lib/python3.10/asyncio/events.py:80, in _run()
#      79 try:
# ---> 80     self._context.run(self._callback, *self._args)
#      81 except (SystemExit, KeyboardInterrupt):
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py:542, in dispatch_queue()
#     541 try:
# --> 542     await self.process_one()
#     543 except Exception:
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py:531, in process_one()
#     530         return
# --> 531 await dispatch(*args)
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py:437, in dispatch_shell()
#     436     if inspect.isawaitable(result):
# --> 437         await result
#     438 except Exception:
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py:359, in execute_request()
#     358 self._associate_new_top_level_threads_with(parent_header)
# --> 359 await super().execute_request(stream, ident, parent)
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py:775, in execute_request()
#     774 if inspect.isawaitable(reply_content):
# --> 775     reply_content = await reply_content
#     777 # Flush output before sending the reply.
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py:446, in do_execute()
#     445 if accepts_params["cell_id"]:
# --> 446     res = shell.run_cell(
#     447         code,
#     448         store_history=store_history,
#     449         silent=silent,
#     450         cell_id=cell_id,
#     451     )
#     452 else:
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py:549, in run_cell()
#     548 self._last_traceback = None
# --> 549 return super().run_cell(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3051, in run_cell()
#    3050 try:
# -> 3051     result = self._run_cell(
#    3052         raw_cell, store_history, silent, shell_futures, cell_id
#    3053     )
#    3054 finally:
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3106, in _run_cell()
#    3105 try:
# -> 3106     result = runner(coro)
#    3107 except BaseException as e:
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner()
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3311, in run_cell_async()
#    3308 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3311 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3312        interactivity=interactivity, compiler=compiler, result=result)
#    3314 self.last_execution_succeeded = not has_raised
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3493, in run_ast_nodes()
#    3492     asy = compare(code)
# -> 3493 if await self.run_code(code, result, async_=asy):
#    3494     return True
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3553, in run_code()
#    3552     else:
# -> 3553         exec(code_obj, self.user_global_ns, self.user_ns)
#    3554 finally:
#    3555     # Reset our crash handler in place
#
# Cell In[12], line 11
#      10 ode_train_step = make_ode_train_step(neural_ode_model)
# ---> 11 neural_ode_params, opt_state, loss = ode_train_step(neural_ode_params, opt_state, ic_batch, ts, y_batch)
#      13 epoch_loss += loss
#
# Cell In[11], line 15, in ode_train_step()
#      14     return jnp.mean((pred_y - y_true) ** 2)
# ---> 15 loss, grads = jax.value_and_grad(loss_fn)(params)
#      16 updates, opt_state = optimizer.update(grads, opt_state)
#
# Cell In[11], line 13, in loss_fn()
#      12 def loss_fn(params):
# ---> 13     pred_y = solve_neural_ode(model, params, y0, ts)
#      14     return jnp.mean((pred_y - y_true) ** 2)
#
# Cell In[9], line 5, in solve_neural_ode()
#       4 saveat = SaveAt(ts=ts)
# ----> 5 sol = diffeqsolve(term, solver, t0=ts[0], t1=ts[-1], dt0=0.1, y0=y0, saveat=saveat)
#       6 return sol.ys
#
# File ~/.local/lib/python3.10/site-packages/diffrax/_integrate.py:1416, in diffeqsolve()
#    1412 #
#    1413 # Main loop
#    1414 #
# -> 1416 final_state, aux_stats = adjoint.loop(
#    1417     args=args,
#    1418     terms=terms,
#    1419     solver=solver,
#    1420     stepsize_controller=stepsize_controller,
#    1421     event=event,
#    1422     saveat=saveat,
#    1423     t0=t0,
#    1424     t1=t1,
#    1425     dt0=dt0,
#    1426     max_steps=max_steps,
#    1427     init_state=init_state,
#    1428     throw=throw,
#    1429     passed_solver_state=passed_solver_state,
#    1430     passed_controller_state=passed_controller_state,
#    1431     progress_meter=progress_meter,
#    1432 )
#    1434 #
#    1435 # Finish up
#    1436 #
#
# File ~/.local/lib/python3.10/site-packages/equinox/_module/_prebuilt.py:33, in __call__()
#      32 __tracebackhide__ = True
# ---> 33 return self.__func__(self.__self__, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/diffrax/_adjoint.py:299, in loop()
#     298     msg = None
# --> 299 final_state = self._loop(
#     300     terms=terms,
#     301     saveat=saveat,
#     302     init_state=init_state,
#     303     max_steps=max_steps,
#     304     inner_while_loop=inner_while_loop,
#     305     outer_while_loop=outer_while_loop,
#     306     **kwargs,
#     307 )
#     308 if msg is not None:
#
# File ~/.local/lib/python3.10/site-packages/diffrax/_integrate.py:638, in loop()
#     636     return new_state
# --> 638 final_state = outer_while_loop(
#     639     cond_fun, body_fun, init_state, max_steps=max_steps, buffers=_outer_buffers
#     640 )
#     641 result = final_state.result
#
# File /usr/lib/python3.10/contextlib.py:79, in inner()
#      78 with self._recreate_cm():
# ---> 79     return func(*args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/equinox/internal/_loop/loop.py:107, in while_loop()
#     106     del kind, base
# --> 107     return checkpointed_while_loop(
#     108         cond_fun,
#     109         body_fun,
#     110         init_val,
#     111         max_steps=max_steps,
#     112         buffers=buffers,
#     113         checkpoints=checkpoints,
#     114     )
#     115 elif kind == "bounded":
#
# File ~/.local/lib/python3.10/site-packages/equinox/internal/_loop/checkpointed.py:249, in checkpointed_while_loop()
#     248 vjp_arg = (init_val_, body_fun_)
# --> 249 final_val_ = _checkpointed_while_loop(
#     250     vjp_arg, cond_fun_, checkpoints, buffers_, max_steps
#     251 )
#     252 _, _, _, final_val = _stop_gradient_on_unperturbed(init_val_, final_val_, body_fun_)
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       9     y_batch = Ys[i]
#      10     ode_train_step = make_ode_train_step(neural_ode_model)
# ---> 11     neural_ode_params, opt_state, loss = ode_train_step(neural_ode_params, opt_state, ic_batch, ts, y_batch)
#      13     epoch_loss += loss
#      14 epoch_loss /= (ICs.shape[0] // batch_size)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:292, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     287 if config.no_tracing.value:
#     288   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     289                      "`jit`, but 'no_tracing' is set")
#     291 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, box_data,
# --> 292  executable, pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     294 maybe_fastpath_data = _get_fastpath_data(
#     295     executable, out_tree, args_flat, out_flat, attrs_tracked, box_data,
#     296     jaxpr.effects, jaxpr.consts, jit_info.abstracted_axes, pgle_profiler)
#     298 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:139, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     138 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 139   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     141   for arg in args_flat:
#     142     dispatch.check_arg(arg)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:686, in _infer_params(fun, ji, args, kwargs)
#     683   with (_internal_use_concrete_mesh(phys_mesh),
#     684         mesh_lib.use_abstract_mesh(phys_mesh.abstract_mesh)):
#     685     return _infer_params_internal(fun, ji, args, kwargs)
# --> 686 return _infer_params_internal(fun, ji, args, kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:710, in _infer_params_internal(fun, ji, args, kwargs)
#     707 entry = _infer_params_cached(fun, ji, signature, avals, ctx_mesh)
#     709 if entry.pjit_params is None:
# --> 710   p, args_flat = _infer_params_impl(
#     711       fun, ji, ctx_mesh, dbg, args, kwargs, in_avals=avals)
#     712   if p.attrs_tracked or p.box_data or p.params['jaxpr'].jaxpr.is_high:
#     713     return p, p.consts + args_flat
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:606, in _infer_params_impl(***failed resolving arguments***)
#     599 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     600     in_shardings_treedef, in_shardings_leaves,
#     601     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     602     in_avals, in_tree, flat_fun.debug_info, device_or_backend_set, have_kwargs)
#     604 attr_token = _attr_cache_index(flat_fun, in_type)
# --> 606 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     607     flat_fun, in_type, attr_token, IgnoreKey(ji.inline))
#     609 if config.mutable_array_checks.value:
#     610   _check_no_aliased_closed_over_refs(dbg, (*jaxpr.consts, *consts), explicit_args)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:471, in cache.<locals>.memoized_fun(fun, *args)
#     469 if do_explain := explain and config.explain_cache_misses.value:
#     470   start = time.time()
# --> 471 ans = call(fun, *args)
#     472 if do_explain:
#     473   explain(fun, cache is new_cache, cache, key, time.time() - start)  # type: ignore
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1414, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1412     attrs_tracked = []
#    1413   else:
# -> 1414     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(fun, in_type)
#    1416 if config.debug_key_reuse.value:
#    1417   # Import here to avoid circular imports
#    1418   from jax.experimental.key_reuse._core import check_key_reuse_jaxpr  # pytype: disable=import-error
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2292, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower)
#    2290 try:
#    2291   with core.set_current_trace(trace):
# -> 2292     ans = fun.call_wrapped(*in_tracers)
#    2293   _check_returned_jaxtypes(fun.debug_info, ans)
#    2294   out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# Cell In[11], line 15, in make_ode_train_step.<locals>.ode_train_step(params, opt_state, y0, ts, y_true)
#      13     pred_y = solve_neural_ode(model, params, y0, ts)
#      14     return jnp.mean((pred_y - y_true) ** 2)
# ---> 15 loss, grads = jax.value_and_grad(loss_fn)(params)
#      16 updates, opt_state = optimizer.update(grads, opt_state)
#      17 params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:510, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     508   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     509 if not has_aux:
# --> 510   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     511 else:
#     512   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:2179, in _vjp(fun, has_aux, *primals)
#    2177 if not has_aux:
#    2178   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2179   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2180   out_tree = out_tree()
#    2181 else:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:292, in vjp(traceable, primals, has_aux)
#     290 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     291   if not has_aux:
# --> 292     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     293   else:
#     294     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:277, in linearize(traceable, *primals, **kwargs)
#     275 _, in_tree = tree_flatten(((primals, primals), {}))
#     276 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 277 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     278 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     279 if any(not out_primal_pval.is_known() for out_primal_pval in out_primals_pvals):
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:614, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     612 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate, fun.debug_info)
#     613 with core.set_current_trace(trace):
# --> 614   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     615   assert not env
#     616 del trace, fun
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:628, in trace_to_subjaxpr_nounits(f, trace, instantiate, debug_info, in_pvals)
#     620 @lu.transformation2
#     621 def trace_to_subjaxpr_nounits(
#     622     f: Callable,
#    (...)
#     625     debug_info: core.DebugInfo,
#     626     in_pvals: Sequence[PartialVal]):
#     627   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 628   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     629       f, trace, instantiate, in_pvals, debug_info)
#     630   out_pvals = [t.pval for t in out_tracers]
#     631   del out_tracers
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:661, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     659 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     660 with core.set_current_trace(trace):
# --> 661   ans = f(*in_args)
#     662 assert isinstance(ans, (list, tuple)), (
#     663     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     664 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     665     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:81, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      78 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      79        else contextlib.nullcontext())
#      80 with ctx:
# ---> 81   out_primals, out_tangents = f(tag, primals, tangents)
#      82 if type(instantiate) is bool:
#      83   instantiate = [instantiate] * len(out_tangents)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:136, in jvp_subtrace(f, tag, primals, tangents)
#     133   in_tracers = [maybe_jvp_tracer(trace, x, t)
#     134                 for x, t in zip(primals, tangents)]
#     135   with core.set_current_trace(trace):
# --> 136     ans = f(*in_tracers)
#     137   out = unzip2(map(trace.to_primal_tangent_pair, ans))
#     138 return out
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# Cell In[11], line 13, in make_ode_train_step.<locals>.ode_train_step.<locals>.loss_fn(params)
#      12 def loss_fn(params):
# ---> 13     pred_y = solve_neural_ode(model, params, y0, ts)
#      14     return jnp.mean((pred_y - y_true) ** 2)
#
# Cell In[9], line 5, in solve_neural_ode(rhs_net, params, y0, ts)
#       3 solver = Dopri5()
#       4 saveat = SaveAt(ts=ts)
# ----> 5 sol = diffeqsolve(term, solver, t0=ts[0], t1=ts[-1], dt0=0.1, y0=y0, saveat=saveat)
#       6 return sol.ys
#
#     [... skipping hidden 3 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:292, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     287 if config.no_tracing.value:
#     288   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     289                      "`jit`, but 'no_tracing' is set")
#     291 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, box_data,
# --> 292  executable, pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     294 maybe_fastpath_data = _get_fastpath_data(
#     295     executable, out_tree, args_flat, out_flat, attrs_tracked, box_data,
#     296     jaxpr.effects, jaxpr.consts, jit_info.abstracted_axes, pgle_profiler)
#     298 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:155, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     153   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     154 else:
# --> 155   out_flat = pjit_p.bind(*args_flat, **p.params)
#     156   compiled = None
#     157   profiler = None
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:500, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     498   raise NotImplementedError(msg)
#     499 with core.set_current_trace(self.parent_trace):
# --> 500   primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     502 if primitive.multiple_results:
#     503   return [maybe_jvp_tracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:2244, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs)
#    2242 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    2243 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 2244 outputs = pjit_p.bind(
#    2245     *primals_in, *_filter_zeros_in(tangents_in),
#    2246     jaxpr=jaxpr_jvp,
#    2247     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    2248     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    2249     in_layouts=(*in_layouts, *_filter_zeros_in(in_layouts)),
#    2250     out_layouts=(*out_layouts, *_filter_zeros_out(out_layouts)),
#    2251     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    2252     ctx_mesh=ctx_mesh,
#    2253     name=name,
#    2254     keep_unused=keep_unused,
#    2255     inline=inline,
#    2256     compiler_options_kvs=compiler_options_kvs)
#    2258 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    2259 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:229, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     227 if primitive in custom_partial_eval_rules:
#     228   tracers = map(self.to_jaxpr_tracer, tracers)
# --> 229   return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     230 else:
#     231   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:2362, in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *in_tracers)
#    2359 known_ins = tuple(pv.is_known() for pv in in_pvals)
#    2360 unknown_ins = tuple(not k for k in known_ins)
#    2361 known_jaxpr, unknown_jaxpr, unknown_outs, res_out_avals, in_fwd_res = \
# -> 2362     pe.partial_eval_jaxpr_nounits_fwd(jaxpr, unknown_ins, instantiate=False)
#    2363 unknown_outs = tuple(unknown_outs)  # type: ignore[assignment]
#    2364 known_outs = tuple(not uk for uk in unknown_outs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:997, in partial_eval_jaxpr_nounits_fwd(jaxpr, unknowns, instantiate)
#     992 def partial_eval_jaxpr_nounits_fwd(
#     993     jaxpr: ClosedJaxpr, unknowns: Sequence[bool],
#     994     instantiate: bool | Sequence[bool],
#     995 ) -> tuple[ClosedJaxpr, ClosedJaxpr, list[bool], list[AbstractValue], list[int | None]]:
#     996   instantiate = tuple(instantiate) if isinstance(instantiate, list) else instantiate
# --> 997   return _partial_eval_jaxpr_nounits(jaxpr, tuple(unknowns), instantiate, True)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:1030, in _partial_eval_jaxpr_nounits(jaxpr, in_unknowns, instantiate, fwd)
#    1027   return [*known_vals_out, *residuals]
#    1029 known_avals = [a for a, uk in zip(jaxpr.in_aval_qdds, in_unknowns) if not uk]
# -> 1030 jaxpr_known, _, consts_known, () = trace_to_jaxpr_dynamic(
#    1031     lu.wrap_init(fun, debug_info=f.debug_info), known_avals)
#    1032 (out_unknowns, jaxpr_unknown, res_avals, fwds), = cell  # pytype: disable=bad-unpacking
#    1034 if config.enable_checks.value:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2292, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower)
#    2290 try:
#    2291   with core.set_current_trace(trace):
# -> 2292     ans = fun.call_wrapped(*in_tracers)
#    2293   _check_returned_jaxtypes(fun.debug_info, ans)
#    2294   out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:1013, in _partial_eval_jaxpr_nounits.<locals>.fun(*known_vals_in)
#    1009 in_pvals = [PartialVal.unknown(next(unknown_avals)) if uk
#    1010             else PartialVal.known(next(known_vals_in_)) for uk in in_unknowns]
#    1011 assert next(known_vals_in_, None) is next(unknown_avals, None) is None
#    1012 jaxpr_unknown_, (fwds, out_pvals, residuals, ()) = trace_to_subjaxpr_nounits_fwd(
# -> 1013     f, TraceTag(), jaxpr.jaxpr.debug_info, instantiate).call_wrapped(in_pvals)
#    1014 jaxpr_unknown = convert_constvars_jaxpr(jaxpr_unknown_)
#    1015 out_unknowns = [not pval.is_known() for pval in out_pvals]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:690, in trace_to_subjaxpr_nounits_fwd(f, tag, debug_info, instantiate, in_pvals)
#     688 trace = JaxprTrace(parent_trace, current_name_stack, tag)
#     689 with core.set_current_trace(trace):
# --> 690   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     691       f, trace, instantiate, in_pvals, debug_info)
#     692 out_pvals = [t.pval for t in out_tracers]
#     694 # Which out_consts (aka residuals) are just forwarded inputs? Check obj id.
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:661, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     659 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     660 with core.set_current_trace(trace):
# --> 661   ans = f(*in_args)
#     662 assert isinstance(ans, (list, tuple)), (
#     663     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     664 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     665     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:296, in jaxpr_as_fun(closed_jaxpr, *args)
#     287 @curry
#     288 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
#     289   # TODO(dougalm): remove this hack when we add contexts to jaxpr.
#    (...)
#     293   # context modifications. In the meantime, disabling the checks when we
#     294   # round-trip prevents those ops producing spurious errors.
#     295   with config.debug_nans(False):
# --> 296     return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:630, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     627 traceback = eqn.source_info.traceback if propagate_source_info else None
#     628 with source_info_util.user_context(
#     629     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 630   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     631 if eqn.primitive.multiple_results:
#     632   foreach(write, eqn.outvars, ans)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:229, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     227 if primitive in custom_partial_eval_rules:
#     228   tracers = map(self.to_jaxpr_tracer, tracers)
# --> 229   return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     230 else:
#     231   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1953, in _while_partial_eval(trace, cond_nconsts, cond_jaxpr, body_nconsts, body_jaxpr, *tracers)
#    1951 carry_uk = carry_init_uk
#    1952 for _ in range(1 + len(carry_uk)):
# -> 1953   body_jaxpr_known, _, carry_out_uk, body_res_avals = pe.partial_eval_jaxpr_nounits(
#    1954       body_jaxpr, body_consts_uk + carry_uk, instantiate=carry_uk)
#    1955   if carry_out_uk == carry_uk:
#    1956     break
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:990, in partial_eval_jaxpr_nounits(jaxpr, unknowns, instantiate)
#     933 """Unzip a jaxpr in two by data dependence into 'known' and 'unknown' parts.
#     934
#     935 That is, given a jaxpr and a sequence of booleans indicating which jaxpr
#    (...)
#     987 passed to jaxpr_unknown (as leading inputs).
#     988 """
#     989 instantiate = tuple(instantiate) if isinstance(instantiate, list) else instantiate
# --> 990 return _partial_eval_jaxpr_nounits(jaxpr, tuple(unknowns), instantiate, False)[:-1]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:1030, in _partial_eval_jaxpr_nounits(jaxpr, in_unknowns, instantiate, fwd)
#    1027   return [*known_vals_out, *residuals]
#    1029 known_avals = [a for a, uk in zip(jaxpr.in_aval_qdds, in_unknowns) if not uk]
# -> 1030 jaxpr_known, _, consts_known, () = trace_to_jaxpr_dynamic(
#    1031     lu.wrap_init(fun, debug_info=f.debug_info), known_avals)
#    1032 (out_unknowns, jaxpr_unknown, res_avals, fwds), = cell  # pytype: disable=bad-unpacking
#    1034 if config.enable_checks.value:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2292, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower)
#    2290 try:
#    2291   with core.set_current_trace(trace):
# -> 2292     ans = fun.call_wrapped(*in_tracers)
#    2293   _check_returned_jaxtypes(fun.debug_info, ans)
#    2294   out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:1013, in _partial_eval_jaxpr_nounits.<locals>.fun(*known_vals_in)
#    1009 in_pvals = [PartialVal.unknown(next(unknown_avals)) if uk
#    1010             else PartialVal.known(next(known_vals_in_)) for uk in in_unknowns]
#    1011 assert next(known_vals_in_, None) is next(unknown_avals, None) is None
#    1012 jaxpr_unknown_, (fwds, out_pvals, residuals, ()) = trace_to_subjaxpr_nounits_fwd(
# -> 1013     f, TraceTag(), jaxpr.jaxpr.debug_info, instantiate).call_wrapped(in_pvals)
#    1014 jaxpr_unknown = convert_constvars_jaxpr(jaxpr_unknown_)
#    1015 out_unknowns = [not pval.is_known() for pval in out_pvals]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:690, in trace_to_subjaxpr_nounits_fwd(f, tag, debug_info, instantiate, in_pvals)
#     688 trace = JaxprTrace(parent_trace, current_name_stack, tag)
#     689 with core.set_current_trace(trace):
# --> 690   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     691       f, trace, instantiate, in_pvals, debug_info)
#     692 out_pvals = [t.pval for t in out_tracers]
#     694 # Which out_consts (aka residuals) are just forwarded inputs? Check obj id.
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:661, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     659 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     660 with core.set_current_trace(trace):
# --> 661   ans = f(*in_args)
#     662 assert isinstance(ans, (list, tuple)), (
#     663     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     664 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     665     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:296, in jaxpr_as_fun(closed_jaxpr, *args)
#     287 @curry
#     288 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
#     289   # TODO(dougalm): remove this hack when we add contexts to jaxpr.
#    (...)
#     293   # context modifications. In the meantime, disabling the checks when we
#     294   # round-trip prevents those ops producing spurious errors.
#     295   with config.debug_nans(False):
# --> 296     return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:635, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     633   else:
#     634     write(eqn.outvars[0], ans)
# --> 635   clean_up_dead_vars(eqn, env, lu)
#     636 return map(read, jaxpr.outvars)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:3564, in clean_up_dead_vars(eqn, env, last_used)
#    3561 def clean_up_dead_vars(eqn: JaxprEqn, env: dict[Var, Any],
#    3562                        last_used: dict[Var, JaxprEqn | None]):
#    3563   """Remove all eqn.invars from env if eqn is the last time they were used."""
# -> 3564   for v in {v for v in eqn.invars if not isinstance(v, Literal)}:
#    3565     if last_used[v] is eqn:
#    3566       # Delete ref to variable when it is no longer needed by next equations.
#    3567       del env[v]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:3564, in <setcomp>(.0)
#    3561 def clean_up_dead_vars(eqn: JaxprEqn, env: dict[Var, Any],
#    3562                        last_used: dict[Var, JaxprEqn | None]):
#    3563   """Remove all eqn.invars from env if eqn is the last time they were used."""
# -> 3564   for v in {v for v in eqn.invars if not isinstance(v, Literal)}:
#    3565     if last_used[v] is eqn:
#    3566       # Delete ref to variable when it is no longer needed by next equations.
#    3567       del env[v]
#
# KeyboardInterrupt:

# %%
# Plot prediction
y0_test = ICs[0]
y_true = Ys[0]
y_pred = solve_neural_ode(neural_ode_model, neural_ode_params, y0_test, ts)

plt.plot(ts, y_true[:, 0], label="A true")
plt.plot(ts, y_pred[:, 0], '--', label="A pred")
plt.plot(ts, y_true[:, 1], label="B true")
plt.plot(ts, y_pred[:, 1], '--', label="B pred")
plt.plot(ts, y_true[:, 2], label="C true")
plt.plot(ts, y_pred[:, 2], '--', label="C pred")
plt.legend()
plt.title("Neural ODE Prediction vs Ground Truth")
plt.grid(True)

# %% [markdown]
# ## 🧬 Implementing DeepONet
# We now define a Deep Operator Network with separate branch and trunk networks.

# %%
import jax.numpy as jnp
from flax import linen as nn
from typing import Callable, Tuple

class MLP(nn.Module):
    features: Tuple[int, ...]
    activation: Callable = nn.relu

    @nn.compact
    def __call__(self, x):
        for feat in self.features[:-1]:
            x = self.activation(nn.Dense(feat)(x))
        return nn.Dense(self.features[-1])(x)

class DeepONet(nn.Module):
    branch_layers: Tuple[int, ...] = (128, 128, 128)
    trunk_layers: Tuple[int, ...] = (128, 128, 128)
    latent_dim: int = 128
    output_dim: int = 3
    activation: Callable = nn.tanh

    def setup(self):
        trunk_features = self.trunk_layers + (self.latent_dim,)
        self.trunk_net = MLP(features=trunk_features, activation=self.activation)

        # Define 3 separate branch networks
        self.branch_nets = [
            MLP(features=self.branch_layers + (self.latent_dim,), activation=self.activation)
            for _ in range(self.output_dim)
        ]

    @nn.compact
    def __call__(self, ic, t):
        B, N = t.shape  # B=batch size, N=time points
        trunk_in = t.reshape(-1, 1)  # (B*N, 1)
        trunk_out = self.trunk_net(trunk_in).reshape(B, N, self.latent_dim)  # (B, N, D)

        # For each branch network, compute output and dot with trunk
        outputs = []
        for branch_net in self.branch_nets:
            branch_out = branch_net(ic).reshape(B, self.latent_dim)  # (B, D)
            y = jnp.einsum("bnd,bd->bn", trunk_out, branch_out)  # (B, N)
            outputs.append(y[..., None])  # (B, N, 1)

        return jnp.concatenate(outputs, axis=-1)  # (B, N, 3)

# %%
deeponet_model = DeepONet()
deeponet_state = create_train_state(rng, deeponet_model)

def deeponet_loss_fn(params, ic, t, y_true):
    y_pred = deeponet_model.apply({'params': params}, ic, t)
    return jnp.mean((y_pred - y_true) ** 2)

@jax.jit
def deeponet_train_step(state, ic, t, y_true):
    loss, grads = jax.value_and_grad(deeponet_loss_fn)(state.params, ic, t, y_true)
    return state.apply_gradients(grads=grads), loss

# %%
n_epochs = 200
deeponet_losses = []

for epoch in range(n_epochs):
    epoch_loss = 0.0
    for i in range(0, ICs.shape[0], batch_size):
        ic_batch = ICs[i:i+batch_size]
        t_batch = Ts[i:i+batch_size]
        y_batch = Ys[i:i+batch_size]
        deeponet_state, loss = deeponet_train_step(deeponet_state, ic_batch, t_batch, y_batch)
        epoch_loss += loss
    epoch_loss /= (ICs.shape[0] // batch_size)
    deeponet_losses.append(epoch_loss)
    if epoch % 20 == 0:
        print(f"[DeepONet] Epoch {epoch}, Loss = {epoch_loss:.4e}")
# Out:
# [DeepONet] Epoch 0, Loss = 1.1608e+01
# [DeepONet] Epoch 20, Loss = 3.0082e-03
# [DeepONet] Epoch 40, Loss = 1.1716e-02
# [DeepONet] Epoch 60, Loss = 5.6264e-04
# [DeepONet] Epoch 80, Loss = 5.0175e-03
# [DeepONet] Epoch 100, Loss = 5.9741e-04
# [DeepONet] Epoch 120, Loss = 3.1818e-03
# [DeepONet] Epoch 140, Loss = 2.7331e-03
# [DeepONet] Epoch 160, Loss = 2.0379e-04
# [DeepONet] Epoch 180, Loss = 4.8964e-04

# %%
# Evaluate DeepONet
ic_test = ICs[0:1]
t_test = Ts[0:1]
y_true = Ys[0]
y_pred = deeponet_model.apply({'params': deeponet_state.params}, ic_test, t_test)[0]

plt.plot(ts, y_true[:, 0], label="A true")
plt.plot(ts, y_pred[:, 0], '--', label="A pred")
plt.plot(ts, y_true[:, 1], label="B true")
plt.plot(ts, y_pred[:, 1], '--', label="B pred")
plt.plot(ts, y_true[:, 2], label="C true")
plt.plot(ts, y_pred[:, 2], '--', label="C pred")
plt.legend()
plt.title("DeepONet Prediction vs Ground Truth")
plt.grid(True)
